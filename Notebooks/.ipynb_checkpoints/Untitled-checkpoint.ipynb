# %%
import warnings

warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Run the CSV
nba_stats = pd.read_excel('../Clean data/top_8_teams_2017-2018.xlsx')
nba_stats
# Out:
#     Team  Game       Date  Home Opponent WINorLOSS  TeamPoints  \
# 1    BOS    14 2017-11-12  Home      TOR         W          95
# 2    BOS    55 2018-02-06  Away      TOR         L          91
# 3    BOS     3 2017-10-20  Away      PHI         W         102
# 4    BOS    23 2017-11-30  Home      PHI         W         108
# 5    BOS     1 2017-10-17  Away      CLE         L          99
# 6    BOS    41 2018-01-03  Home      CLE         W         102
# 7    BOS    21 2017-11-25  Away      IND         W         108
# 8    BOS    33 2017-12-18  Away      IND         W         112
# 9    BOS     6 2017-10-28  Away      MIA         W          96
# 10   BOS    34 2017-12-20  Home      MIA         L          89
# 11   BOS     2 2017-10-18  Home      MIL         L         100
# 12   BOS     5 2017-10-26  Away      MIL         W          96
# 13   BOS    56 2018-02-08  Away      WAS         W         110
# 14   BOS    37 2017-12-25  Home      WAS         L         103
# ...

# %%
nba_stats.drop(nba_stats.columns[nba_stats.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
nba_stats
# Out:
#     Team  Game       Date  Home Opponent WINorLOSS  TeamPoints  \
# 1    BOS    14 2017-11-12  Home      TOR         W          95
# 2    BOS    55 2018-02-06  Away      TOR         L          91
# 3    BOS     3 2017-10-20  Away      PHI         W         102
# 4    BOS    23 2017-11-30  Home      PHI         W         108
# 5    BOS     1 2017-10-17  Away      CLE         L          99
# 6    BOS    41 2018-01-03  Home      CLE         W         102
# 7    BOS    21 2017-11-25  Away      IND         W         108
# 8    BOS    33 2017-12-18  Away      IND         W         112
# 9    BOS     6 2017-10-28  Away      MIA         W          96
# 10   BOS    34 2017-12-20  Home      MIA         L          89
# 11   BOS     2 2017-10-18  Home      MIL         L         100
# 12   BOS     5 2017-10-26  Away      MIL         W          96
# 13   BOS    56 2018-02-08  Away      WAS         W         110
# 14   BOS    37 2017-12-25  Home      WAS         L         103
# ...

# %%
nba_stats.WINorLOSS[nba_stats.WINorLOSS == 'W'] = 0
nba_stats.WINorLOSS[nba_stats.WINorLOSS == 'L'] = 1
nba_stats
# Out:
#     Team  Game       Date  Home Opponent WINorLOSS  TeamPoints  \
# 1    BOS    14 2017-11-12  Home      TOR         0          95
# 2    BOS    55 2018-02-06  Away      TOR         1          91
# 3    BOS     3 2017-10-20  Away      PHI         0         102
# 4    BOS    23 2017-11-30  Home      PHI         0         108
# 5    BOS     1 2017-10-17  Away      CLE         1          99
# 6    BOS    41 2018-01-03  Home      CLE         0         102
# 7    BOS    21 2017-11-25  Away      IND         0         108
# 8    BOS    33 2017-12-18  Away      IND         0         112
# 9    BOS     6 2017-10-28  Away      MIA         0          96
# 10   BOS    34 2017-12-20  Home      MIA         1          89
# 11   BOS     2 2017-10-18  Home      MIL         1         100
# 12   BOS     5 2017-10-26  Away      MIL         0          96
# 13   BOS    56 2018-02-08  Away      WAS         0         110
# 14   BOS    37 2017-12-25  Home      WAS         1         103
# ...

# %%
nba_stats.Home[nba_stats.Home == 'Home'] = 0
nba_stats.Home[nba_stats.Home == 'Away'] = 1
nba_stats
# Out:
#     Team  Game       Date Home Opponent WINorLOSS  TeamPoints  OpponentPoints  \
# 1    BOS    14 2017-11-12    0      TOR         0          95              94
# 2    BOS    55 2018-02-06    1      TOR         1          91             111
# 3    BOS     3 2017-10-20    1      PHI         0         102              92
# 4    BOS    23 2017-11-30    0      PHI         0         108              97
# 5    BOS     1 2017-10-17    1      CLE         1          99             102
# 6    BOS    41 2018-01-03    0      CLE         0         102              88
# 7    BOS    21 2017-11-25    1      IND         0         108              98
# 8    BOS    33 2017-12-18    1      IND         0         112             111
# 9    BOS     6 2017-10-28    1      MIA         0          96              90
# 10   BOS    34 2017-12-20    0      MIA         1          89              90
# 11   BOS     2 2017-10-18    0      MIL         1         100             108
# ...

# %%
uniqueTeams = nba_stats['Team'].unique()
dictTeams = {}
cnt = 1
for team in uniqueTeams:
    dictTeams[team] = cnt
    cnt+=1

dictTeams

for key,value in dictTeams.items():
    print('{} = {}'.format(key,value))
    #nba_stats['Team']== key and replace Team with value
    #nba_stats['Opponent'] == key and replace Opponent with value
# Out:
# BOS = 1
# CLE = 2
# GSW = 3
# HOU = 4
# IND = 5
# MIA = 6
# MIL = 7
# MIN = 8
# NOP = 9
# OKC = 10
# PHI = 11
# POR = 12
# SAS = 13
# TOR = 14
# WAS = 15

# %%
dictTeams['UTA'] = 16
dictTeams
# Out:
# {'BOS': 1,
#  'CLE': 2,
#  'GSW': 3,
#  'HOU': 4,
#  'IND': 5,
#  'MIA': 6,
#  'MIL': 7,
#  'MIN': 8,
#  'NOP': 9,
#  'OKC': 10,
#  'PHI': 11,
#  'POR': 12,
#  'SAS': 13,
#  'TOR': 14,
#  'WAS': 15,
#  'UTA': 16}

# %%
nba_stats.replace(dictTeams, inplace=True)
nba_stats
# Out:
#      Team  Game       Date  Home  Opponent  WINorLOSS  TeamPoints  \
# 1       1    14 2017-11-12     0        14          0          95
# 2       1    55 2018-02-06     1        14          1          91
# 3       1     3 2017-10-20     1        11          0         102
# 4       1    23 2017-11-30     0        11          0         108
# 5       1     1 2017-10-17     1         2          1          99
# 6       1    41 2018-01-03     0         2          0         102
# 7       1    21 2017-11-25     1         5          0         108
# 8       1    33 2017-12-18     1         5          0         112
# 9       1     6 2017-10-28     1         6          0          96
# 10      1    34 2017-12-20     0         6          1          89
# 11      1     2 2017-10-18     0         7          1         100
# 12      1     5 2017-10-26     1         7          0          96
# 13      1    56 2018-02-08     1        15          0         110
# ...

# %%
nba_stats.drop(nba_stats.columns[nba_stats.columns.str.contains('Date',case = False)],axis = 1, inplace = True)
nba_stats
# Out:
#      Team  Game  Home  Opponent  WINorLOSS  TeamPoints  OpponentPoints  \
# 1       1    14     0        14          0          95              94
# 2       1    55     1        14          1          91             111
# 3       1     3     1        11          0         102              92
# 4       1    23     0        11          0         108              97
# 5       1     1     1         2          1          99             102
# 6       1    41     0         2          0         102              88
# 7       1    21     1         5          0         108              98
# 8       1    33     1         5          0         112             111
# 9       1     6     1         6          0          96              90
# 10      1    34     0         6          1          89              90
# 11      1     2     0         7          1         100             108
# 12      1     5     1         7          0          96              89
# ...

# %%
nba_stats = nba_stats.dropna(how='any')
nba_stats
# Out:
#      Team  Game  Home  Opponent  WINorLOSS  TeamPoints  OpponentPoints  \
# 1       1    14     0        14          0          95              94
# 2       1    55     1        14          1          91             111
# 3       1     3     1        11          0         102              92
# 4       1    23     0        11          0         108              97
# 5       1     1     1         2          1          99             102
# 6       1    41     0         2          0         102              88
# 7       1    21     1         5          0         108              98
# 9       1     6     1         6          0          96              90
# 10      1    34     0         6          1          89              90
# 11      1     2     0         7          1         100             108
# 12      1     5     1         7          0          96              89
# 13      1    56     1        15          0         110             104
# ...

# %%
nba_stats.drop(nba_stats.columns[nba_stats.columns.str.contains('TeamPoints', case = False)],axis = 1, inplace = True)
nba_stats
# Out:
#      Team  Game  Home  Opponent  WINorLOSS  OpponentPoints  FieldGoals  \
# 1       1    14     0        14          0              94          35
# 2       1    55     1        14          1             111          33
# 3       1     3     1        11          0              92          35
# 4       1    23     0        11          0              97          40
# 5       1     1     1         2          1             102          36
# 6       1    41     0         2          0              88          41
# 7       1    21     1         5          0              98          45
# 9       1     6     1         6          0              90          34
# 10      1    34     0         6          1              90          30
# 11      1     2     0         7          1             108          39
# 12      1     5     1         7          0              89          33
# 13      1    56     1        15          0             104          39
# ...

# %%
nba_stats.drop(nba_stats.columns[nba_stats.columns.str.contains('OpponentPoints',case = False)],axis = 1, inplace = True)
nba_stats
# Out:
#      Team  Game  Home  Opponent  WINorLOSS  FieldGoals  FieldGoalsAttempted  \
# 1       1    14     0        14          0          35                   87
# 2       1    55     1        14          1          33                   83
# 3       1     3     1        11          0          35                   84
# 4       1    23     0        11          0          40                   79
# 5       1     1     1         2          1          36                   88
# 6       1    41     0         2          0          41                   92
# 7       1    21     1         5          0          45                   80
# 9       1     6     1         6          0          34                   81
# 10      1    34     0         6          1          30                   80
# 11      1     2     0         7          1          39                   91
# 12      1     5     1         7          0          33                   78
# ...

# %%
nba_stats
nba_stats.head()
# Out:
#    Team  Game  Home  Opponent  WINorLOSS  FieldGoals  FieldGoalsAttempted  \
# 1     1    14     0        14          0          35                   87
# 2     1    55     1        14          1          33                   83
# 3     1     3     1        11          0          35                   84
# 4     1    23     0        11          0          40                   79
# 5     1     1     1         2          1          36                   88
#
#    FieldGoals.  X3PointShots  X3PointShotsAttempted       ...        \
# 1        0.402            10                     26       ...
# 2        0.398            10                     23       ...
# 3        0.417            10                     29       ...
# 4        0.506            12                     29       ...
# 5        0.409             8                     32       ...
#
#    Opp.FreeThrows  Opp.FreeThrowsAttempted  Opp.FreeThrows.  Opp.OffRebounds  \
# ...

# %%
X = nba_stats.drop("WINorLOSS", axis=1)
y = nba_stats["WINorLOSS"]
print(X.shape, y.shape)
# Out:
# (239, 36) (239,)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, = train_test_split(X, y, random_state=1, stratify=y)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
nba_stats.dtypes
# Out:
# Team                          int64
# Game                          int64
# Home                          int64
# Opponent                      int64
# WINorLOSS                     int64
# FieldGoals                    int64
# FieldGoalsAttempted           int64
# FieldGoals.                 float64
# X3PointShots                  int64
# X3PointShotsAttempted         int64
# X3PointShots.               float64
# FreeThrows                    int64
# FreeThrowsAttempted           int64
# FreeThrows.                 float64
# OffRebounds                   int64
# TotalRebounds                 int64
# Assists                       int64
# Steals                        int64
# Blocks                        int64
# Turnovers                     int64
# TotalFouls                    int64
# Opp.FieldGoals                int64
# Opp.FieldGoalsAttempted       int64
# Opp.FieldGoals.             float64
# Opp.3PointShots               int64
# Opp.3PointShotsAttempted      int64
# ...

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9666666666666667

# %%
predictions = classifier.predict(X_test)
table = pd.DataFrame({"Prediction": predictions, "Actual": y_test})
table['Correct'] = table.Prediction == table.Actual
table
# Out:
#      Prediction  Actual  Correct
# 166           0       0     True
# 176           1       1     True
# 137           1       1     True
# 121           1       1     True
# 24            0       0     True
# 51            0       0     True
# 207           1       1     True
# 209           0       0     True
# 20            0       0     True
# 215           1       1     True
# 28            1       1     True
# 177           1       1     True
# 29            0       0     True
# 3             0       0     True
# 183           1       1     True
# 142           1       1     True
# 146           0       0     True
# 41            0       0     True
# 135           1       1     True
# 192           1       1     True
# 17            0       0     True
# 57            1       1     True
# 113           1       1     True
# 167           0       0     True
# 129           1       1     True
# 145           0       0     True
# 52            1       1     True
# ...

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        31
#            1       1.00      0.93      0.96        29
#
#    micro avg       0.97      0.97      0.97        60
#    macro avg       0.97      0.97      0.97        60
# weighted avg       0.97      0.97      0.97        60

# %%
import pickle

with open('nbamodel.pkl', 'wb') as file:
    pickle.dump(classifier, file)

# %%
classifier = pickle.load(open('nbamodel.pkl', 'rb'))

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.feature_selection import RFE
rfe = RFE(classifier, 3)
fit = rfe.fit(X, y)
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))
# Out:
# Num Features: 3
# Selected Features: [False False False False  True False False False False False False False
#  False False False False False False False False  True False False False
#  False False  True False False False False False False False False False]
# Feature Ranking: [28 26  7 12  1 32 20  3 24 19  2  8 21 16 15 30  5 23 25 18  1 11 29  4
#  27 34  1 31 22 17 10 13  9 33  6 14]

# %%
nba_stats1 = nba_stats[['Home', 'FieldGoals', 'X3PointShots', 'WINorLOSS', 'FreeThrows', 'FreeThrowsAttempted', 'Steals', 'Opp.3PointShots', 'Opp.TotalRebounds', 'Opp.Steals', 'Opp.Turnovers']]
nba_stats1
# Out:
#      Home  FieldGoals  X3PointShots  WINorLOSS  FreeThrows  \
# 1       0          35            10          0          15
# 2       1          33            10          1          15
# 3       1          35            10          0          22
# 4       0          40            12          0          16
# 5       1          36             8          1          19
# 6       0          41            12          0           8
# 7       1          45            10          0           8
# 9       1          34             6          0          22
# 10      0          30            13          1          16
# 11      0          39            11          1          11
# 12      1          33            11          0          19
# 13      1          39             9          0          23
# 14      0          39            14          1          11
# 15      0          37             8          0          17
# 16      1          44            13          1          19
# ...

# %%
X = nba_stats1.drop("WINorLOSS", axis=1)
y = nba_stats1["WINorLOSS"]
print(X.shape, y.shape)
# Out:
# (239, 10) (239,)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, = train_test_split(X, y, random_state=1, stratify=y)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7150837988826816
# Testing Data Score: 0.6

# %%
predictions = classifier.predict(X_test)
table = pd.DataFrame({"Prediction": predictions, "Actual": y_test})
table['Correct'] = table.Prediction == table.Actual
table
# Out:
#      Prediction  Actual  Correct
# 166           0       0     True
# 176           0       1    False
# 137           0       1    False
# 121           1       1     True
# 24            1       0    False
# 51            1       0    False
# 207           1       1     True
# 209           0       0     True
# 20            1       0    False
# 215           1       1     True
# 28            0       1    False
# 177           1       1     True
# 29            1       0    False
# 3             1       0    False
# 183           0       1    False
# 142           1       1     True
# 146           0       0     True
# 41            0       0     True
# 135           1       1     True
# 192           0       1    False
# 17            1       0    False
# 57            1       1     True
# 113           1       1     True
# 167           1       0    False
# 129           1       1     True
# 145           0       0     True
# 52            1       1     True
# ...

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.52      0.57        31
#            1       0.57      0.69      0.62        29
#
#    micro avg       0.60      0.60      0.60        60
#    macro avg       0.61      0.60      0.60        60
# weighted avg       0.61      0.60      0.60        60

# %%
with open('nbamodel2.pkl', 'wb') as file:
    pickle.dump(classifier, file)

# %%
classifier = pickle.load(open('nbamodel2.pkl', 'rb'))

# %%
nba_stats2 = nba_stats[['Team', 'Home', 'Opponent', 'WINorLOSS', 'FieldGoals.', 'X3PointShots', 'Opp.FieldGoals.', 'Opp.3PointShots.', ]]
nba_stats2
# Out:
#      Team  Home  Opponent  WINorLOSS  FieldGoals.  X3PointShots  \
# 1       1     0        14          0        0.402            10
# 2       1     1        14          1        0.398            10
# 3       1     1        11          0        0.417            10
# 4       1     0        11          0        0.506            12
# 5       1     1         2          1        0.409             8
# 6       1     0         2          0        0.446            12
# 7       1     1         5          0        0.563            10
# 9       1     1         6          0        0.420             6
# 10      1     0         6          1        0.375            13
# 11      1     0         7          1        0.429            11
# 12      1     1         7          0        0.423            11
# 13      1     1        15          0        0.464             9
# 14      1     0        15          1        0.481            14
# 15      1     0         4          0        0.451             8
# ...

# %%
X = nba_stats2.drop("WINorLOSS", axis=1)
y = nba_stats2["WINorLOSS"]
print(X.shape, y.shape)
# Out:
# (239, 7) (239,)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, = train_test_split(X, y, random_state=1, stratify=y)

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6759776536312849
# Testing Data Score: 0.6333333333333333

# %%
predictions = classifier.predict(X_test)
table = pd.DataFrame({"Prediction": predictions, "Actual": y_test})
table['Correct'] = table.Prediction == table.Actual
table
# Out:
#      Prediction  Actual  Correct
# 166           0       0     True
# 176           0       1    False
# 137           0       1    False
# 121           1       1     True
# 24            0       0     True
# 51            0       0     True
# 207           1       1     True
# 209           0       0     True
# 20            0       0     True
# 215           1       1     True
# 28            0       1    False
# 177           1       1     True
# 29            1       0    False
# 3             1       0    False
# 183           0       1    False
# 142           1       1     True
# 146           1       0    False
# 41            0       0     True
# 135           1       1     True
# 192           1       1     True
# 17            1       0    False
# 57            1       1     True
# 113           0       1    False
# 167           0       0     True
# 129           1       1     True
# 145           0       0     True
# 52            0       1    False
# ...

# %%
import sys
sys.path.append('/Users/adeliamanuel/anaconda3/envs/keras/lib/python3.7/site-packages')
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.63        31
#            1       0.61      0.66      0.63        29
#
#    micro avg       0.63      0.63      0.63        60
#    macro avg       0.63      0.63      0.63        60
# weighted avg       0.63      0.63      0.63        60

# %%
with open('nbamodel3.pkl', 'wb') as file:
    pickle.dump(classifier, file)
    
classifier = pickle.load(open('nbamodel3.pkl', 'rb'))
